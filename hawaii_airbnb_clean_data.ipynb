# %%
import pandas as pd
import numpy as np
from my_functions import bed_bath_rating, cols_to_drop, missing_room_count

# %%
hawaii = pd.read_csv('data/listings_hawaii.csv')

hawaii.head()
# Out:
#        id                                               name  host_id  \
# 0    5269  Rental unit in Kamuela · ★4.65 · 1 bedroom · 1...     7620
# 1   81566  Rental unit in Haleiwa · ★4.67 · 2 bedrooms · ...   442490
# 2    5387  Rental unit in Captain Cook · ★4.65 · Studio ·...     7878
# 3   81582  Home in Pāhoa · ★4.94 · 2 bedrooms · 3 beds · ...   442698
# 4  300379  Rental unit in Honolulu · ★4.58 · 1 bedroom · ...   677327
#
#    host_name neighbourhood_group         neighbourhood   latitude   longitude  \
# 0  Lea & Pat              Hawaii          South Kohala  20.027400 -155.702000
# 1      Susan            Honolulu      North Shore Oahu  21.589247 -158.111008
# 2     Edward              Hawaii            South Kona  19.430810 -155.880690
# 3  Elizabeth              Hawaii                  Puna  19.434280 -155.216090
# 4    Richard            Honolulu  Primary Urban Center  21.301450 -157.844130
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
hawaii_df = bed_bath_rating(hawaii)
hawaii_df.head()
# Out:
#        id                                               name  host_id  \
# 0    5269  Rental unit in Kamuela · ★4.65 · 1 bedroom · 1...     7620
# 1   81566  Rental unit in Haleiwa · ★4.67 · 2 bedrooms · ...   442490
# 2    5387  Rental unit in Captain Cook · ★4.65 · Studio ·...     7878
# 3   81582  Home in Pāhoa · ★4.94 · 2 bedrooms · 3 beds · ...   442698
# 4  300379  Rental unit in Honolulu · ★4.58 · 1 bedroom · ...   677327
#
#    host_name neighbourhood_group         neighbourhood   latitude   longitude  \
# 0  Lea & Pat              Hawaii          South Kohala  20.027400 -155.702000
# 1      Susan            Honolulu      North Shore Oahu  21.589247 -158.111008
# 2     Edward              Hawaii            South Kona  19.430810 -155.880690
# 3  Elizabeth              Hawaii                  Puna  19.434280 -155.216090
# 4    Richard            Honolulu  Primary Urban Center  21.301450 -157.844130
#
#          room_type  price  ...  last_review  reviews_per_month  \
# ...

# %%
hawaii_df = cols_to_drop(hawaii_df)
hawaii_df.head()
# Out:
#        id  host_id  host_name neighbourhood_group         neighbourhood  \
# 0    5269     7620  Lea & Pat              Hawaii          South Kohala
# 1   81566   442490      Susan            Honolulu      North Shore Oahu
# 2    5387     7878     Edward              Hawaii            South Kona
# 3   81582   442698  Elizabeth              Hawaii                  Puna
# 4  300379   677327    Richard            Honolulu  Primary Urban Center
#
#     latitude   longitude        room_type  price  minimum_nights  \
# 0  20.027400 -155.702000  Entire home/apt    144               5
# 1  21.589247 -158.111008  Entire home/apt    250               4
# 2  19.430810 -155.880690  Entire home/apt    105               5
# 3  19.434280 -155.216090  Entire home/apt    119               2
# 4  21.301450 -157.844130     Private room     81               3
#
#    number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# ...

# %%
missing_room_count(hawaii_df)
# Out:
#                  room_type  bedrooms  beds  bath
# room_type
# Entire home/apt          0         0     0     0
# Hotel room               0         0     0     0
# Private room             0         0     0     0
# Shared room              0         0     0     0

# %%
hawaii_df['neighbourhood'], hawaii_df['neighbourhood_group'] = hawaii_df['neighbourhood_group'], hawaii_df['neighbourhood']

hawaii_df.head()
# Out:
#        id  host_id  host_name   neighbourhood_group neighbourhood   latitude  \
# 0    5269     7620  Lea & Pat          South Kohala        Hawaii  20.027400
# 1   81566   442490      Susan      North Shore Oahu      Honolulu  21.589247
# 2    5387     7878     Edward            South Kona        Hawaii  19.430810
# 3   81582   442698  Elizabeth                  Puna        Hawaii  19.434280
# 4  300379   677327    Richard  Primary Urban Center      Honolulu  21.301450
#
#     longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0 -155.702000  Entire home/apt    144               5                 27
# 1 -158.111008  Entire home/apt    250               4                260
# 2 -155.880690  Entire home/apt    105               5                208
# 3 -155.216090  Entire home/apt    119               2                181
# 4 -157.844130     Private room     81               3                237
#
# ...

# %%
hawaii_df.drop(columns=['neighbourhood'], inplace=True)

hawaii_df.head()
# Out:
#        id  host_id  host_name   neighbourhood_group   latitude   longitude  \
# 0    5269     7620  Lea & Pat          South Kohala  20.027400 -155.702000
# 1   81566   442490      Susan      North Shore Oahu  21.589247 -158.111008
# 2    5387     7878     Edward            South Kona  19.430810 -155.880690
# 3   81582   442698  Elizabeth                  Puna  19.434280 -155.216090
# 4  300379   677327    Richard  Primary Urban Center  21.301450 -157.844130
#
#          room_type  price  minimum_nights  number_of_reviews  \
# 0  Entire home/apt    144               5                 27
# 1  Entire home/apt    250               4                260
# 2  Entire home/apt    105               5                208
# 3  Entire home/apt    119               2                181
# 4     Private room     81               3                237
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               0.18                               4               180
# ...

# %%
hawaii_df.to_csv('data/listings_hawaii_clean.csv', index=False)
